# %% [markdown]
# # Web Scraping and Geotagging Project

# %% [markdown]
# ## Setup and Imports

# %%
import requests
import pandas as pd
import folium
from folium.plugins import MarkerCluster
from sqlalchemy import create_engine
from bs4 import BeautifulSoup
from geopy.geocoders import Nominatim

# %% [markdown]
# ## Web Scraping

# %%
# Target URL for web scraping
url = 'https://www.scrapethissite.com/pages/simple/'

# Sending a GET request to the URL
response = requests.get(url)

# Parsing the HTML content using BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Scraping data from the specified divs
divs = soup.find_all('div', class_='col-md-4 country')

# Initializing lists to store scraped data
countries = []
capitals = []
populations = []
areas = []

# Looping through each country div to extract data
for country in divs:
    # Scraping country name
    country_name = country.find('h3', class_='country-name').text.strip() if country.find('h3', class_='country-name') else "CHECK"

    # Scraping capital
    capital = country.find('span', class_='country-capital').text.strip() if country.find('span', class_='country-capital') else "CHECK"

    # Scraping population
    population_element = country.find('strong', text="Population:")
    population = population_element.find_next_sibling().text.strip() if population_element else "CHECK"

    # Scraping area
    area = country.find('span', class_='country-area').text.strip() if country.find('span', class_='country-area') else "CHECK"

    # Appending scraped data to respective lists
    countries.append(country_name)
    capitals.append(capital)
    populations.append(population)
    areas.append(area)

# Creating a DataFrame from the scraped data
data = {
    "Country": countries,
    "Capital": capitals,
    "Population": populations,
    "Areas": areas
}
df = pd.DataFrame(data)

df
# Out:
# C:\Users\vicen\AppData\Local\Temp\ipykernel_1900\3815939274.py:28: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   population_element = country.find('strong', text="Population:")
#                   Country           Capital Population      Areas
# 0                 Andorra  Andorra la Vella      84000      468.0
# 1    United Arab Emirates         Abu Dhabi    4975593    82880.0
# 2             Afghanistan             Kabul   29121286   647500.0
# 3     Antigua and Barbuda        St. John's      86754      443.0
# 4                Anguilla        The Valley      13254      102.0
# ..                    ...               ...        ...        ...
# 245                 Yemen             Sanaa   23495361   527970.0
# 246               Mayotte         Mamoudzou     159042      374.0
# 247          South Africa          Pretoria   49000000  1219912.0
# 248                Zambia            Lusaka   13460305   752614.0
# 249              Zimbabwe            Harare   11651858   390580.0
#
# [250 rows x 4 columns]

# %% [markdown]
# ## Geotagging

# %%
# Combining city and country for geocoding
city_country = [f"{capital}, {country}" for capital, country in zip(capitals, countries)]

# Initializing geocoder
geolocator = Nominatim(user_agent="sample")

# Initializing lists for latitude and longitude
latitudes = []
longitudes = []

# Looping through city_country list for geocoding
for location in city_country:
    try:
        result = geolocator.geocode(location)
        if result:
            latitudes.append(result.latitude)
            longitudes.append(result.longitude)
        else:
            latitudes.append(None)
            longitudes.append(None)
    except Exception as e:
        print(f"Error geocoding {location}: {e}")

# Adding geotag data to the DataFrame
df['Latitude'] = latitudes
df['Longitude'] = longitudes

df
# Out:
#                   Country           Capital Population      Areas   Latitude  \
# 0                 Andorra  Andorra la Vella      84000      468.0  42.506939
# 1    United Arab Emirates         Abu Dhabi    4975593    82880.0  24.453835
# 2             Afghanistan             Kabul   29121286   647500.0  34.526011
# 3     Antigua and Barbuda        St. John's      86754      443.0  17.118457
# 4                Anguilla        The Valley      13254      102.0  18.214586
# ..                    ...               ...        ...        ...        ...
# 245                 Yemen             Sanaa   23495361   527970.0  15.353857
# 246               Mayotte         Mamoudzou     159042      374.0 -12.780414
# 247          South Africa          Pretoria   49000000  1219912.0 -25.745928
# 248                Zambia            Lusaka   13460305   752614.0 -15.357609
# 249              Zimbabwe            Harare   11651858   390580.0 -17.856703
#
#      Longitude
# 0     1.521247
# 1    54.377401
# 2    69.177684
# 3   -61.844851
# 4   -63.051776
# ..         ...
# 245  44.205884
# 246  45.227976
# 247  28.187910
# 248  29.165309
# 249  31.060158
#
# [250 rows x 6 columns]

# %% [markdown]
# ## Database Upload

# %%
# Database connection details
db_name = "DATABASE NAME"
db_user = "DATABASE USER"
db_password = "USER PASSWORD"
db_host = "localhost"
db_port = "5432"

# Creating connection string
connection_str = f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}'

# Creating engine to connect to PostgreSQL
engine = create_engine(connection_str)

# Table name for database upload
table_name = 'Countries_info'

# Uploading DataFrame to PostgreSQL database
df.to_sql(table_name, engine, if_exists='append', index=False)

# Disposing engine after database upload
engine.dispose()

# %% [markdown]
# ## Data Mapping

# %%
m = folium.Map(location=df[["Latitude","Longitude"]].mean().to_list(), zoom_start=2)
marker_cluster = MarkerCluster().add_to(m)
df_filtered = df.dropna(subset=["Latitude","Longitude"])

for i, r in df_filtered.iterrows():
    location = (r["Latitude"], r["Longitude"])
    folium.Marker(location=location,
                  popup=r['Capital'],
                  tooltip=r['Capital']) \
        .add_to(marker_cluster)
    
m.save("map.html")

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d2176065042b3bcb9fd69b4a1fae1e50 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d2176065042b3bcb9fd69b4a1fae1e50&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d2176065042b3bcb9fd69b4a1fae1e50 = L.map(
#                 &quot;map_d2176065042b3bcb9fd69b4a1fae1e50&quot;,
#                 {
#                     center: [17.29371197252066, 13.529138366048477],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_78a463daefdf514647d88baf59740733 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_78a463daefdf514647d88baf59740733.addTo(map_d2176065042b3bcb9fd69b4a1fae1e50);
#
#
#             var marker_cluster_3e9968b3af6996669fa3a4fd7bf4c7f2 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_9df241af7720f81403b5158f272e50dc = L.marker(
#                 [42.5069391, 1.5212467],
#                 {}
#             ).addTo(marker_cluster_3e9968b3af6996669fa3a4fd7bf4c7f2);
#
#
#         var popup_713b4a693f13828f14ad20ff1834186a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f9b835ba56d2a6afcb9b4b9994ab3644 = $(`&lt;div id=&quot;html_f9b835ba56d2a6afcb9b4b9994ab3644&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Andorra la Vella&lt;/div&gt;`)[0];
#                 popup_713b4a693f13828f14ad20ff1834186a.setContent(html_f9b835ba56d2a6afcb9b4b9994ab3644);
#
#
#
#         marker_9df241af7720f81403b5158f272e50dc.bindPopup(popup_713b4a693f13828f14ad20ff1834186a)
#         ;
#
#
#
#
#             marker_9df241af7720f81403b5158f272e50dc.bindTooltip(
#                 `&lt;div&gt;
#                      Andorra la Vella
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fde5dec38dd4411f10ee9c3fd372758f = L.marker(
#                 [24.4538352, 54.3774014],
#                 {}
#             ).addTo(marker_cluster_3e9968b3af6996669fa3a4fd7bf4c7f2);
#
#
#         var popup_b16b5e225ee7e584308a841997cb3897 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7559a9615e307987f84d13c1e5173a0a = $(`&lt;div id=&quot;html_7559a9615e307987f84d13c1e5173a0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Abu Dhabi&lt;/div&gt;`)[0];
#                 popup_b16b5e225ee7e584308a841997cb3897.setContent(html_7559a9615e307987f84d13c1e5173a0a);
#
#
#
#         marker_fde5dec38dd4411f10ee9c3fd372758f.bindPopup(popup_b16b5e225ee7e584308a841997cb3897)
#         ;
#
#
#
#
#             marker_fde5dec38dd4411f10ee9c3fd372758f.bindTooltip(
#                 `&lt;div&gt;
#                      Abu Dhabi
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0ad66c19722e2fe5009d974af3b7c77b = L.marker(
#                 [34.5260109, 69.1776838],
#                 {}
#             ).addTo(marker_cluster_3e9968b3af6996669fa3a4fd7bf4c7f2);
#
#
#         var popup_98314df495bde9d0726eaad0f10a92f3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7e0147cbec51c91bc7a0f83f7ecd53d2 = $(`&lt;div id=&quot;html_7e0147cbec51c91bc7a0f83f7ecd53d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kabul&lt;/div&gt;`)[0];
#                 popup_98314df495bde9d0726eaad0f10a92f3.setContent(html_7e0147cbec51c91bc7a0f83f7ecd53d2);
#
#
#
#         marker_0ad66c19722e2fe5009d974af3b7c77b.bindPopup(popup_98314df495bde9d0726eaad0f10a92f3)
#         ;
#
#
#
#
#             marker_0ad66c19722e2fe5009d974af3b7c77b.bindTooltip(
#                 `&lt;div&gt;
#                      Kabul
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1e359b563b998cbd18941375114f5acd = L.marker(
#                 [17.1184569, -61.8448509],
#                 {}
#             ).addTo(marker_cluster_3e9968b3af6996669fa3a4fd7bf4c7f2);
#
#
#         var popup_c04d180e07262d90ad3564d35ce0e7f4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_86fac77e196443f4c91fc006fd3cb1e8 = $(`&lt;div id=&quot;html_86fac77e196443f4c91fc006fd3cb1e8&qu
